# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_fashion = pd.read_json('AMAZON_FASHION.json', lines=True)
df_fashionmeta = pd.read_json('meta_AMAZON_FASHION.json', lines=True)

# %%
df_fashion
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0             5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1             2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2             4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3             2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4             3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...         ...       ...          ...             ...         ...
# 883631        5      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
# 883632        5      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
# 883633        3      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
# 883634        3      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
# 883635        5      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                reviewerName  \
# 0                     Tracy
# 1                 Sonja Lau
# 2                  Kathleen
# 3               Jodi Stoner
# ...

# %%
df_fashionmeta
# Out:
#                                                     title  \
# 0       Slime Time Fall Fest [With CDROM and Collector...
# 1       XCC Qi promise new spider snake preparing men'...
# 2                      Magical Things I Really Do Do Too!
# 3                      Ashes to Ashes, Oranges to Oranges
# 4       Aether & Empire #1 - 2016 First Printing Comic...
# ...                                                   ...
# 186632  JT Women's Elegant Off Shoulder Chiffon Maxi L...
# 186633  Microcosm Retro Vintage Black Crochet Lace One...
# 186634  Lookatool Classic Plain Vintage Army Military ...
# 186635  Edith Windsor Women's Deep V-neck Beaded Sequi...
# 186636  Aeropostale Women's Sun & Waves Crop Cami L Gr...
#
#                                                     image  \
# 0       [https://images-na.ssl-images-amazon.com/image...
# 1       [https://images-na.ssl-images-amazon.com/image...
# 2       [https://images-na.ssl-images-amazon.com/image...
# ...

# %%
df_fashion.loc[:, "timestamp"] = pd.to_datetime(
    df_fashion["reviewTime"],
    format="%m %d, %Y")

# %%
df_fashion1=df_fashion[['asin', 'timestamp']].groupby('asin')

# %%
df_fashion2=df_fashion1.max()-df_fashion1.min()
df_fashion2
# Out:
#            timestamp
# asin
# 0764443682    0 days
# 1291691480    0 days
# 1940280001    0 days
# 1940735033 1254 days
# 1940967805    0 days
# ...              ...
# B01HJGXL4O    0 days
# B01HJGZVYW    0 days
# B01HJH7JY6    0 days
# B01HJHF97K    0 days
# B01HJHTH5U  552 days
#
# [186189 rows x 1 columns]

# %%
df3= df.drop(df2[df2.timestamp < 180].index)

# %%
int(df2.timestamp)

# %%
type(df2.timestamp)

# %%
df3 = df_fashion2.timestamp >180
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4f9e0935e949> in <module>
# ----> 1 df3 = df_fashion2.timestamp >180
#
# ~/anaconda3/envs/smm635/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1182
#    1183         elif is_timedelta64_dtype(self):
# -> 1184             res_values = dispatch_to_index_op(op, self, other, pd.TimedeltaIndex)
#    1185             return self._constructor(res_values, index=self.index, name=res_name)
#    1186
#
# ~/anaconda3/envs/smm635/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_index_op(op, left, right, index_class)
#     628         left_idx = left_idx._shallow_copy(freq=None)
#     629     try:
# --> 630         result = op(left_idx, right)
#     631     except NullFrequencyError:
# ...
